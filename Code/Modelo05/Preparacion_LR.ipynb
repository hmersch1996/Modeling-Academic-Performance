# %%
#pip install tqdm==4.63.0

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import keras
import tensorflow as tf

import tensorflow.keras.preprocessing.image 
import tensorflow.keras.models

tf.keras.backend.clear_session()  # Para restablecer fácilmente el estado del portátil.

# %%
#Librerias necesarias para implementacion de algoritmo genetico
from __future__ import print_function

from evolver import Evolver

from tqdm import tqdm

import logging

import sys

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import linear_model, model_selection
import seaborn as sns
import tensorflow as tf
from tensorflow.keras import backend as Kc

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.callbacks import EarlyStopping, Callback, ModelCheckpoint




from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from pickle import dump,load

y=load( open('labels.pkl', 'rb'))
x_train=load( open('x_train.pkl', 'rb'))
x_test=load( open('x_test.pkl', 'rb'))
y_train=load( open('y_train.pkl', 'rb'))
y_test=load( open('y_test.pkl', 'rb'))

yLR_train =load( open('y_trainLR.pkl', 'rb'))
yLR_test =load( open('y_testLR.pkl', 'rb'))

# %%
#Librerias necesarias para trabajar con datasets
import pandas as pd
import numpy as np
from sklearn import linear_model, model_selection

#Librerias necesarias para aplicar redes neuronales
import tensorflow as tf

df= pd.read_csv("Modelo04.csv", sep=",",index_col=False)
df.head()
# Out:
#    Cod.Asign  Cod.Car.Sec Codificado  Recursante  Anho  Ciclo  1P  2P  3P  4P  \
# 0       2402                      20           0  2012      1   0   0   0   0
# 1       2402                      33           1  2012      1  11  14   0   0
# 2       2402                      20           1  2012      1  24  23   0   0
# 3       2402                      33           1  2012      1  11  14   0   0
# 4       2402                      33           0  2012      1  11   4   0   0
#
#    Taller  Aprobado
# 0       0         0
# 1       8         1
# 2       9         1
# 3       8         1
# 4       8         0

# %%
modelo5=df.drop(columns=['2P','3P','4P','Taller'],axis=1)
modelo5.head()
# Out:
#    Cod.Asign  Cod.Car.Sec Codificado  Recursante  Anho  Ciclo  1P  Aprobado
# 0       2402                      20           0  2012      1   0         0
# 1       2402                      33           1  2012      1  11         1
# 2       2402                      20           1  2012      1  24         1
# 3       2402                      33           1  2012      1  11         1
# 4       2402                      33           0  2012      1  11         0

# %%
#Preparacion de datos para su introduccion en la regresion
data=modelo5[['Cod.Asign','Cod.Car.Sec Codificado','Recursante','Anho','Ciclo','1P']]
[filas,columnas]=data.shape
labels=df[['Aprobado']]

#Como labels figura como string, es necesario cambiarlos a valores enteros
data = np.array(data)
labels = np.array(labels)
labels=np.ravel(labels)

# %%
from pickle import dump,load
dump(data, open('data.pkl', 'wb'))
dump(labels, open('labels.pkl', 'wb'))
dump(columnas, open('columnas.pkl', 'wb'))

# %%
#physical_devices = tf.config.experimental.list_physical_devices('GPU')

# %%
#tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
#Implemento el programa con el algoritmo genetico, porque aqui separa los datos de la forma que necesito
import main as ge
lista=ge.main()
# Out:
# 28/03/2022 01:34:39 PM - INFO - ***generate(generations, population, all_possible_genes, dataset)***
# 28/03/2022 01:34:39 PM - INFO - ***Now in generation 1 of 30***
# 28/03/2022 01:34:39 PM - INFO - --------------------------------------------------------------------------------
# 28/03/2022 01:34:39 PM - INFO - {'nb_layers': 3, 'activation': 'sigmoid', 'optimizer': 'adam', 'nb_neurons': [32, 64, 16, 128, 32, 64]}
# 28/03/2022 01:34:39 PM - INFO - Acc: 0.00%
# 28/03/2022 01:34:39 PM - INFO - UniID: 1
# 28/03/2022 01:34:39 PM - INFO - Mom and Dad: 0 0
# 28/03/2022 01:34:39 PM - INFO - Gen: 1
# 28/03/2022 01:34:39 PM - INFO - Hash: c4b4e17d6c2f855557d9c3406c9d2b2b
# 28/03/2022 01:34:39 PM - INFO - {'nb_layers': 5, 'activation': 'sigmoid', 'optimizer': 'adam', 'nb_neurons': [64, 64, 64, 32, 64, 32]}
# 28/03/2022 01:34:39 PM - INFO - Acc: 0.00%
# 28/03/2022 01:34:39 PM - INFO - UniID: 2
# 28/03/2022 01:34:39 PM - INFO - Mom and Dad: 0 0
# 28/03/2022 01:34:39 PM - INFO - Gen: 1
# ...
